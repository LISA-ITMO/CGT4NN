# %% [markdown]
# # Методы исследования характеристических свойств нейронных сетей с применением теоретико-игрового подхода
#
# - **Теория**: И.В.Томилов ivan-tomilov3@yandex.ru
# - **Реализация**: М.А.Зайцева maria@tail-call.ru
# - **Поддержка CUDA**: А.Е.Григорьева admin@linkennt.ru
# - **Ревизия**: 9
#
# - **Другие ревизии**:
#   - С 1 по 7: [Яндекс Диск](https://disk.yandex.ru/d/aZozDpBlzh_z1A)
#   - 8 и далее: [GitHub releases page](https://github.com/LISA-ITMO/CGT4NN/releases)
# <!-- please do not append text into this block -->

# %% [markdown]
# ## DONE
#
# > Gradient dropout - не все игроки не всегда получают выигрыш
#
# - [x] Больше скрытых слоёв! (теперь их 5)
#     - [x] В скрытых слоях 100-200 нейронов
#     - [x] Попробовать что-то кроме 3 слоёв
#
# Для этого мы вводим класс `AugmentedReLUNetworkMultilayer`, который расширяет
# интерфейс `AugmentedReLUNetwork` параметром `hidden_layers_count`.
#
# - [x] Взять датасет с плохим перфомансом
#     - [x] Какой же из них с плохим перфомансом? Разве не все?
#       - Я думаю, что #4, его $R^2$ ниже -15
#     - $R^2$ увеличился с -15 до -2 🎉
# - [x] $\alpha \in \{ 1, 1.12, 2 \}$
# - [x] Использовать sMAPE вместо $R^2$
#
# ## TODO
#
# - [ ] Пересчитать эксперименты в SMAPe
# - [ ] Если Y -> R это оптимизатор, то плохая композициональность
#
# Best Response: шаг в сторону градиентного спуска
#
# Как сделать композициональнее - функция ошибки это специфический вид слоя
#
# Принимат выход сетки, отдаёт градиент лосс функции
#
# В этом случае у нас весь механизм замыкается, а замкнутой и контролируемой и обучаемой обучение прои
#
# - [ ] Проинтерпретировать как открытую игру
#
# - [ ] Статья про коммуникацию между агентами есть у Ивана
#
# - [ ] Переделываем через композиционную игру
#
# - неархимедовы вероятности, p-адические числа
#
#
# ======
#
# - [ ] не право голоса, а обратная связь отключается
#
# - [ ] F1 Smape
#
# - [ ] сделать к табличкам описание наблюдаем то-то то-то
#
# ## BACKLOG
#
# - [ ] Применять gradient dropout к половине сети и ко всей сети
# - [ ] Варьировать шум от 0 до 1 (а не 2)
# - [ ] Посмотреть, какой архитектурой решали MNIST character recognition на полносвязных сетях
#     - [ ] Reference: https://github.com/ranimeshehata/Feed-Forward-Neural-Network-on-MNIST
#
# - [ ] Использовать инициализацию *He* вместо *Xavier*
#   - [ ] Сравнить
# - [ ] Как оценить устойчивость случайной величины?
# - [ ] На задаче классификации заменять класс $q$ на класс $r$ с заданной вероятностью, а вещественный шум использовать только для регрессии.

# %% [markdown]
# ## Symmetric Mean Absolute Percentage Error (sMAPE)
#
# https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error
#
# Common in time series forecasting
#
# $$ \mathrm{SMAPE} = {100 \over n}  \sum_{t=1}^{n} {{ |F_t - A_t| }\over{ (|A_t| + |F_t|)/2 }} $$
#
# - $A_t$ - actual value
# - $F_t$ - forecast value
#
# Implementation of sMAPE is avaiable in the `torchmetrics` library:
# https://torchmetrics.readthedocs.io/en/v1.0.0/regression/symmetric_mean_absolute_percentage_error.html

# %%
import torch
from torchmetrics import SymmetricMeanAbsolutePercentageError

target = torch.tensor([1, 10, 1e6])
preds = torch.tensor([0.9, 15, 1.2e6])

smape = SymmetricMeanAbsolutePercentageError()
smape(preds, target) # tensor(0.2290)
# Out:
# tensor(0.2290)

# %% [markdown]
# Compare to $R^2$:

# %%
from sklearn.metrics import r2_score

r2_score(preds, target) # 0.9583327812227765
# Out:
# 0.9583327812227765

# %%
from cgtnnlib.LearningTask import is_regression_task
import cgtnnlib.datasets as ds

# list(filter(lambda x: is_regression_task(x.learning_task), ds.datasets))
[ds.datasets[8], ds.datasets[9]]
# Out:
# [Dataset #9 {
#    name: "294_satellite_image"
#    learning_task: LearningTask(name='regression', criterion=MSELoss(), y_dtype=torch.float32)
#    classes_count: 1
#    target: "target"
#    _data: DatasetData(df=      attr1  attr2  attr3  attr4  attr5  attr6  attr7  attr8  attr9  attr10  \
#  0      92.0  115.0  120.0   94.0   84.0  102.0  106.0   79.0   84.0   102.0
#  1      84.0  102.0  106.0   79.0   84.0  102.0  102.0   83.0   80.0   102.0
#  2      84.0  102.0  102.0   83.0   80.0  102.0  102.0   79.0   84.0    94.0
#  3      80.0  102.0  102.0   79.0   84.0   94.0  102.0   79.0   80.0    94.0
#  4      84.0   94.0  102.0   79.0   80.0   94.0   98.0   76.0   80.0   102.0
#  ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
#  6430   60.0   83.0   96.0   85.0   64.0   87.0  100.0   88.0   64.0    83.0
#  6431   64.0   79.0  100.0   85.0   56.0   71.0   96.0   85.0   56.0    68.0
#  6432   56.0   68.0   91.0   81.0   56.0   64.0   91.0   81.0   53.0    64.0
#  6433   56.0   68.0   87.0   74.0   60.0   71.0   91.0   81.0   60.0    64.0
#  6434   60.0   71.0   91.0   81.0   60.0   64.0  104.0   99.0   56.0    64.0
#
#        ...  attr28  attr29  attr30  attr31  attr32  attr33  attr34  attr35  \
#  0     ...   104.0    88.0   121.0   128.0   100.0    84.0   107.0   113.0
#  1     ...   100.0    84.0   107.0   113.0    87.0    84.0    99.0   104.0
#  2     ...    87.0    84.0    99.0   104.0    79.0    84.0    99.0   104.0
#  3     ...    79.0    84.0    99.0   104.0    79.0    84.0   103.0   104.0
#  4     ...    79.0    84.0   103.0   104.0    79.0    79.0   107.0   109.0
#  ...   ...     ...     ...     ...     ...     ...     ...     ...     ...
#  6430  ...    92.0    66.0    87.0   108.0    89.0    63.0    83.0   104.0
#  6431  ...    85.0    66.0    83.0   100.0    85.0    63.0    83.0   100.0
#  6432  ...    81.0    59.0    87.0    96.0    81.0    63.0    83.0    92.0
#  6433  ...    74.0    59.0    83.0    92.0    74.0    59.0    83.0    92.0
#  6434  ...    74.0    59.0    83.0    92.0    70.0    63.0    79.0   108.0
#
#        attr36  target
#  0       87.0     3.0
#  1       79.0     3.0
#  2       79.0     3.0
#  3       79.0     3.0
#  4       87.0     3.0
#  ...      ...     ...
#  6430    85.0     1.0
#  6431    81.0     1.0
#  6432    74.0     5.0
#  6433    70.0     5.0
#  6434    92.0     5.0
#
#  [6435 rows x 37 columns], train_df=      attr1  attr2  attr3  attr4  attr5  attr6  attr7  attr8  attr9  attr10  \
#  651    42.0   30.0  140.0  150.0   42.0   30.0  135.0  150.0   42.0    30.0
#  835    46.0   36.0  122.0  121.0   46.0   36.0  118.0  125.0   46.0    34.0
#  6015   52.0   71.0   84.0   78.0   56.0   75.0   92.0   74.0   56.0    79.0
#  2629   67.0   88.0   89.0   69.0   67.0   84.0   85.0   62.0   63.0    79.0
#  471    43.0   31.0  128.0  135.0   46.0   34.0  133.0  132.0   43.0    31.0
#  ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
#  367    89.0  106.0  105.0   87.0   85.0  102.0  110.0   83.0   85.0   102.0
#  1934   63.0   72.0   74.0   58.0   67.0   75.0   74.0   58.0   71.0    75.0
#  4650   48.0   32.0  128.0  129.0   48.0   37.0  123.0  125.0   59.0    58.0
#  3530   78.0   97.0   97.0   76.0   82.0  102.0  105.0   80.0   85.0   106.0
#  4633   84.0   99.0  108.0   85.0   84.0  103.0  113.0   88.0   88.0   107.0
#
#        ...  attr28  attr29  attr30  attr31  attr32  attr33  attr34  attr35  \
#  651   ...   142.0    44.0    29.0   136.0   146.0    44.0    31.0   136.0
#  835   ...   118.0    46.0    34.0   112.0   114.0    46.0    34.0   112.0
#  6015  ...    80.0    53.0    84.0    97.0    80.0    57.0    84.0    93.0
#  2629  ...    74.0    71.0    87.0    87.0    70.0    68.0    83.0    87.0
#  471   ...   125.0    46.0    34.0   122.0   125.0    46.0    32.0   117.0
#  ...   ...     ...     ...     ...     ...     ...     ...     ...     ...
#  367   ...    85.0    88.0   107.0   113.0    88.0    88.0   107.0   118.0
#  1934  ...    57.0    63.0    73.0    75.0    57.0    63.0    73.0    79.0
#  4650  ...   127.0    46.0    34.0   124.0   124.0    46.0    37.0   119.0
#  3530  ...    92.0    88.0   107.0   113.0    92.0    88.0   107.0   113.0
#  4633  ...    85.0    82.0   100.0   104.0    85.0    90.0   104.0   108.0
#
#        attr36  target
#  651    142.0     2.0
#  835    111.0     2.0
#  6015    76.0     1.0
#  2629    63.0     7.0
#  471    129.0     2.0
#  ...      ...     ...
#  367     88.0     3.0
#  1934    57.0     7.0
#  4650   127.0     2.0
#  3530    88.0     3.0
#  4633    85.0     3.0
#
#  [5148 rows x 37 columns], test_df=      attr1  attr2  attr3  attr4  attr5  attr6  attr7  attr8  attr9  attr10  \
#  3691   46.0   48.0   96.0  103.0   43.0   36.0  104.0  121.0   43.0    34.0
#  1148   72.0   81.0   90.0   65.0   72.0   81.0   94.0   65.0   64.0    69.0
#  649    52.0   45.0  110.0  109.0   46.0   40.0  119.0  139.0   42.0    30.0
#  5218   67.0   73.0   79.0   57.0   67.0   73.0   75.0   60.0   67.0    73.0
#  3618   60.0   94.0  102.0   87.0   60.0   98.0  111.0   87.0   60.0    94.0
#  ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
#  6219   88.0  102.0  102.0   79.0   80.0   98.0   98.0   76.0   80.0    98.0
#  3589   88.0  102.0  115.0   87.0   84.0  106.0  115.0   91.0   84.0   102.0
#  6424   71.0  103.0  118.0   92.0   71.0  103.0  118.0   96.0   68.0   107.0
#  5791   76.0   89.0   94.0   72.0   80.0   94.0   94.0   72.0   80.0    94.0
#  3570   67.0  106.0  119.0   97.0   70.0  111.0  119.0   97.0   63.0   102.0
#
#        ...  attr28  attr29  attr30  attr31  attr32  attr33  attr34  attr35  \
#  3691  ...   107.0    46.0    43.0   112.0   122.0    49.0    49.0   112.0
#  1148  ...    71.0    75.0    87.0    85.0    71.0    71.0    83.0    89.0
#  649   ...   131.0    50.0    40.0   115.0   113.0    50.0    46.0   111.0
#  5218  ...    61.0    64.0    73.0    86.0    61.0    64.0    73.0    78.0
#  3618  ...    92.0    59.0    91.0   104.0    87.0    55.0    87.0   104.0
#  ...   ...     ...     ...     ...     ...     ...     ...     ...     ...
#  6219  ...    83.0    84.0    95.0   100.0    79.0    79.0    99.0    96.0
#  3589  ...    87.0    93.0   107.0   113.0    92.0    88.0   107.0   113.0
#  6424  ...    92.0    70.0   109.0   117.0    96.0    70.0   100.0   108.0
#  5791  ...    75.0    79.0    87.0    93.0    71.0    75.0    91.0    96.0
#  3570  ...    96.0    71.0   112.0   122.0   103.0    68.0   112.0   122.0
#
#        attr36  target
#  3691   118.0     2.0
#  1148    75.0     7.0
#  649    116.0     2.0
#  5218    57.0     7.0
#  3618    87.0     1.0
#  ...      ...     ...
#  6219    79.0     3.0
#  3589    87.0     3.0
#  6424    92.0     1.0
#  5791    75.0     4.0
#  3570    92.0     1.0
#
#  [1287 rows x 37 columns], train_dataset=<torch.utils.data.dataset.TensorDataset object at 0x15ad47bf0>, test_dataset=<torch.utils.data.dataset.TensorDataset object at 0x15b0ce5d0>, train_loader=<torch.utils.data.dataloader.DataLoader object at 0x15b0cf470>, test_loader=<torch.utils.data.dataloader.DataLoader object at 0x15b0cec30>)
#  },
#  Dataset #10 {
#    name: "573_cpu_act"
#    learning_task: LearningTask(name='regression', criterion=MSELoss(), y_dtype=torch.float32)
#    classes_count: 1
#    target: "target"
#    _data: DatasetData(df=      lread  lwrite   scall  sread  swrite   fork       exec     rchar  \
#  0       6.0     2.0  1036.0  103.0   114.0   1.00   1.000000  172076.0
#  1       1.0     0.0  2165.0  205.0   101.0   0.40   1.200000   43107.0
#  2      62.0    77.0  3806.0  258.0   166.0   1.40   1.400000  492142.0
#  3       5.0     0.0  4721.0  256.0   177.0   0.99   2.580000  524787.0
#  4      42.0    55.0  3949.0  249.0   244.0   2.60   4.600000  197289.0
#  ...     ...     ...     ...    ...     ...    ...        ...       ...
#  8187   74.0    49.0  2688.0  176.0   103.0  11.00  32.200001   57714.0
#  8188   29.0    40.0  1906.0  118.0    90.0   0.80   2.000000    8175.0
#  8189    3.0     0.0   926.0   90.0    67.0   0.60   1.000000    5411.0
#  8190    4.0     0.0   418.0   30.0    29.0   0.80   1.000000    3959.0
#  8191    5.0     0.0  1888.0  248.0   215.0   6.20   1.800000  216420.0
#
#           wchar  pgout  ...      pgscan  atch       pgin      ppgin  \
#  0     355965.0   0.00  ...    0.000000  0.00   2.000000   4.000000
#  1      44139.0   4.80  ...  181.399994  0.20  85.400002  88.199997
#  2     268706.0   4.80  ...   79.199997  2.20   7.600000  12.200000
#  3     174964.0  14.51  ...  189.860001  1.99   4.170000  24.850000
#  4     529200.0   4.20  ...    0.000000  1.40   1.800000   2.200000
#  ...        ...    ...  ...         ...   ...        ...        ...
#  8187   38484.0   0.80  ...    0.000000  0.00   0.800000   0.800000
#  8188   27313.0   0.00  ...    0.000000  0.00   0.800000   0.800000
#  8189   19322.0   0.00  ...    0.000000  0.40   0.400000   0.400000
#  8190   10679.0   0.00  ...    0.000000  0.00   0.200000   0.200000
#  8191   39346.0   0.00  ...    0.000000  0.00   7.400000  14.800000
#
#              pflt        vflt  runqsz  freemem   freeswap  target
#  0      73.599998   89.000000     2.0   6527.0  1851864.0    90.0
#  1      19.400000  161.800003     3.0    130.0  1131931.0    88.0
#  2      68.000000  218.800003     5.2    256.0  1314590.0    85.0
#  3      95.629997  248.910004     1.0    233.0   972606.0    81.0
#  4     219.600006  297.200012     3.4    331.0  1013805.0    79.0
#  ...          ...         ...     ...      ...        ...     ...
#  8187  343.200012  649.400024     7.0    314.0  1096333.0    69.0
#  8188   56.200001   78.599998     3.6    166.0  1107088.0    88.0
#  8189   53.400002  154.000000     1.0   1177.0  1020400.0    92.0
#  8190   61.000000   73.199997     2.4   6355.0  1702592.0    96.0
#  8191  296.600006  420.200012     4.6   1628.0  1757696.0    80.0
#
#  [8192 rows x 22 columns], train_df=      lread  lwrite   scall  sread  swrite   fork       exec     rchar  \
#  4780   47.0    65.0  3012.0  269.0   110.0   1.60   3.600000  913173.0
#  5585    4.0     0.0  1917.0  195.0   155.0   1.60   0.600000   89080.0
#  7973    1.0     0.0   304.0   58.0    46.0   0.20   0.200000    1397.0
#  50      0.0     0.0   255.0   32.0    32.0   0.20   0.200000    1430.0
#  155    15.0    15.0   419.0  189.0    62.0   0.20   0.200000  322341.0
#  ...     ...     ...     ...    ...     ...    ...        ...       ...
#  1934    1.0     0.0   864.0   67.0    65.0   0.20   0.200000    4103.0
#  4650   83.0    68.0  5019.0  529.0   453.0  11.98  19.559999  259917.0
#  3530   21.0     1.0  5989.0  673.0   474.0   7.58   3.790000  505990.0
#  4633    6.0     1.0  2745.0  152.0   117.0   1.00   3.800000   12744.0
#  7256    4.0     2.0  1036.0   64.0    51.0   0.40   0.600000  101463.0
#
#           wchar  pgout  ...     pgscan  atch   pgin  ppgin        pflt  \
#  4780   28574.0   7.80  ...  86.400002  0.40  10.20  10.60  117.800003
#  5585   73434.0   0.00  ...   0.000000  0.00   0.60   0.80   80.239998
#  7973   10710.0   1.80  ...   0.000000  0.20   0.00   0.00   16.799999
#  50      7410.0   0.00  ...   0.000000  0.00   0.00   0.00   15.600000
#  155   310319.0   0.00  ...   0.000000  0.00   0.00   0.00   15.600000
#  ...        ...    ...  ...        ...   ...    ...    ...         ...
#  1934   20315.0   0.00  ...   0.000000  0.00   0.60   0.60   15.770000
#  4650   42539.0   6.99  ...   6.590000  5.59  13.57  15.37  536.130005
#  3530   66850.0   0.00  ...   0.000000  0.00   2.40   2.59  381.239990
#  4633   32916.0   0.00  ...   0.000000  0.20  12.40  12.60   55.799999
#  7256   32561.0   1.40  ...   2.200000  4.40   0.60   0.80   30.799999
#
#              vflt  runqsz  freemem   freeswap  target
#  4780  207.600006     1.0    151.0  1088790.0    83.0
#  5585  179.839996     1.0   1156.0  1013640.0    90.0
#  7973   20.799999     1.2    225.0  1759638.0    98.0
#  50     16.799999     1.6   1196.0  1767021.0    91.0
#  155    17.000000     2.4   5333.0  1825789.0    97.0
#  ...          ...     ...      ...        ...     ...
#  1934   21.959999     3.8    232.0  1087649.0    97.0
#  4650  873.049988     5.8    233.0  1091556.0    53.0
#  3530  559.080017     6.8    809.0  1526997.0    70.0
#  4633   99.400002     1.0   1343.0  1113069.0    89.0
#  7256   71.400002     2.2    138.0  1523264.0    96.0
#
#  [6553 rows x 22 columns], test_df=      lread  lwrite   scall  sread  swrite  fork  exec     rchar     wchar  \
#  6294   27.0     0.0  2052.0  163.0    87.0  6.60  19.4  536165.0   28955.0
#  380     1.0     1.0   394.0  208.0    51.0  0.20   0.2  379080.0  332905.0
#  88      4.0     0.0  2921.0  248.0   205.0  3.80   1.4  140416.0   21712.0
#  4202    6.0     2.0  2712.0  259.0   301.0  3.19   1.0   91310.0   26600.0
#  287    15.0     2.0  2374.0  132.0   121.0  0.40   0.8   30493.0   41061.0
#  ...     ...     ...     ...    ...     ...   ...   ...       ...       ...
#  5003    7.0     1.0  3865.0  191.0   179.0  1.60   3.8  186277.0  146745.0
#  6959    8.0     1.0  1652.0  298.0   221.0  5.60   1.8  275926.0  146174.0
#  4798    8.0     7.0  1608.0   79.0    67.0  0.20   0.2   16265.0   17578.0
#  4865   69.0    90.0  3175.0  109.0   128.0  1.00   1.6   66150.0  121835.0
#  1617    2.0     0.0   667.0  131.0   141.0  1.40   4.8    2185.0   12395.0
#
#        pgout  ...      pgscan  atch       pgin      ppgin        pflt  \
#  6294   6.80  ...  151.600006   0.4  64.599998  69.599998  217.399994
#  380    0.00  ...    0.000000   0.0   0.000000   0.000000   15.600000
#  88     3.00  ...    0.000000   0.4   1.000000   1.400000  208.800003
#  4202   1.20  ...    0.000000   0.4   2.400000   2.400000  160.479996
#  287   11.42  ...  164.729996   0.4  15.830000  26.450001   55.110001
#  ...     ...  ...         ...   ...        ...        ...         ...
#  5003   0.00  ...    0.000000   0.0   3.400000   4.400000  133.800003
#  6959   0.00  ...    0.000000   0.0   0.000000   0.000000  257.200012
#  4798   0.00  ...    0.000000   0.0   2.400000   2.400000   38.000000
#  4865   0.00  ...    0.000000   0.0   7.400000   9.400000   59.599998
#  1617   0.00  ...    0.000000   0.0   0.000000   0.000000   98.800003
#
#              vflt  runqsz  freemem   freeswap  target
#  6294  479.799988     2.0    126.0  1089085.0    74.0
#  380    16.799999     2.6   5746.0  1834560.0    97.0
#  88    328.600006     3.0    177.0  1437750.0    86.0
#  4202  250.500000     1.5    304.0  1032599.0    87.0
#  287   184.369995     3.0    150.0  1018368.0    91.0
#  ...          ...     ...      ...        ...     ...
#  5003  202.000000     4.2    825.0  1515533.0    76.0
#  6959  366.200012     2.4   5155.0  1836584.0    84.0
#  4798   87.599998     3.0    691.0   978082.0    94.0
#  4865   88.800003     3.8    735.0  1519203.0    80.0
#  1617   79.199997     1.0   7617.0  1879974.0    95.0
#
#  [1639 rows x 22 columns], train_dataset=<torch.utils.data.dataset.TensorDataset object at 0x15bfeefc0>, test_dataset=<torch.utils.data.dataset.TensorDataset object at 0x15c03bd70>, train_loader=<torch.utils.data.dataloader.DataLoader object at 0x15c039970>, test_loader=<torch.utils.data.dataloader.DataLoader object at 0x15c039c40>)
#  }]

# %% [markdown]
# ## Setup

# %%
from typing import Callable
from cgtnnlib.Dataset import Dataset
from cgtnnlib.constants import LEARNING_RATE, RANDOM_STATE
import cgtnnlib.training as tr
import cgtnnlib.datasets as ds
from cgtnnlib.NoiseGenerator import NoiseGenerator, target_dispersion_scaled_noise, stable_noise, no_noise_generator

iterations = 10
"Число моделей в каждом эксперименте"

pp = [0.0, 0.5, 0.9]
"Набор гиперпараметров gradient dropout"

hidden_layers_count = 5
"Число скрытых слоёв"

inner_layer_size = 150
"Число нейронов в скрытых слоях"

datasets = [ds.datasets[8], ds.datasets[9]]
"Наборы данных, на которых проводить эксперимент"

#output_dir = 'rev9' #3 layers
#output_dir = 'rev9.2' #5 layers
output_dir = 'rev9.3' #5 layers, 
"Папка с результатами"

def dir_path(d: Dataset, p: float, n: NoiseGenerator):
    "Путь каталога эксперимента"
    return f'{output_dir}/dataset{d.number}_p{p}_noise{n.name}/'

def model_path(d: Dataset, p: float, n: NoiseGenerator, N: int):
    "Путь файла PyTorch модели (`.pth`)"
    return f'{output_dir}/dataset{d.number}_p{p}_noise{n.name}/{N}.pth'

def report_filename(d: Dataset, p: float, n: NoiseGenerator, N: int):
    "Имя файла отчёта (`.json`, см. `cgtnnlib/Report.py`)"
    return f'dataset{d.number}_p{p}_noise{n.name}/{N}.json'

def report_path(d: Dataset, p: float, n: NoiseGenerator, N: int):
    "Путь файла отчёта (`.json`, см. `cgtnnlib/Report.py`)"
    return f'{output_dir}/{report_filename(d, p, n, N)}'

def epochs_for_dataset(dataset: Dataset):
    match dataset.number:
        case 9:
            return 20
        case 10:
            return 20
    return 10


ng_makers: list[Callable[[Dataset], NoiseGenerator]] = [
    lambda _: no_noise_generator,
    lambda d: target_dispersion_scaled_noise(
        dataset=d,
        factor=0.03,
        random_seed=RANDOM_STATE + 1,
    ),
    lambda d: stable_noise(
        dataset=d,
        factor=0.03,
        alpha=1,
        beta=0,
    ),
    lambda d: stable_noise(
        dataset=d,
        factor=0.03,
        alpha=1.12,
        beta=0,
    ),
    lambda d: stable_noise(
        dataset=d,
        factor=0.03,
        alpha=2.0,
        beta=1,
    ),
]
"Генераторы шумов для примешивания ко входам"

'setup complete'
# Out:
# 'setup complete'

# %% [markdown]
# Я не понимаю, почему мы примешиваем шум именно ко входам.
# Может, там и не так всё делается.

# %% [markdown]
# ## Training
#
# ### Model B
#
# - both take ~5m 06s to train 10 iterations
# - both on both noises: about ~10m
#
# <hr>
#
# - `ds.datasets['StudentPerformanceFactors']` takes ~2m 30s to train 10 iterations
# - `ds.datasets['wine_quality']` takes ~2m 36s to train 10 iterations
#
# <hr>
#
# - `ds.datasets['allhyper']` takes ~36m to train on all noise generators
#
# ### Model B*
#
# 3 hidden layers:
# - ~15m 38s: Dataset #3, 10 epochs, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $
# - ~9m 30s: Dataset #3, 10 epochs, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $
#
# 5 hidden layers:
# - ~14m 10s: Dataset #3, 10 epochs, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $
#
# - ~93m 23s: Datasets {#3, #6, #9, #10}, 10 epochs, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $

# %%
## Training

import os

from cgtnnlib.Report import Report
from cgtnnlib.nn.AugmentedReLUNetworkMultilayer import AugmentedReLUNetworkMultilayer

for i, dataset in enumerate(datasets):
    for ng_maker in ng_makers:
        for p in pp:
            noise_generator = ng_maker(dataset)
            for iteration in range(iterations):
                os.makedirs(dir_path(dataset, p, noise_generator), exist_ok=True)
                report = Report(
                    dir=output_dir,
                    filename=report_filename(d=dataset, p=p,
                                             n=noise_generator, N=iteration)
                )
                tr.super_train_model(
                    make_model=lambda: AugmentedReLUNetworkMultilayer(
                        inputs_count=dataset.features_count,
                        outputs_count=dataset.classes_count,
                        p=p,
                        inner_layer_size=inner_layer_size,
                        hidden_layers_count=hidden_layers_count,
                    ),
                    model_path=model_path(d=dataset, p=p,
                                          n=noise_generator, N=iteration),
                    dataset=dataset,
                    report=report,
                    epochs=epochs_for_dataset(dataset),
                    learning_rate=LEARNING_RATE,
                    dry_run=False,
                    iteration=iteration,
                    noise_generator=noise_generator,
                )

'training complete'
# Out:
# N=9 #10 gTDS10 p=0.9 E16/20 S547 Loss=735.0890@AugmentedReLUNetworkMultilayer

# %% [markdown]
# ## Evaluation & Analysis
#
# ~2m 44s: Dataset #3, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $
#
# ~15m 32s: Datasets {#3, #6, #9, #10}, 5 ng_makers, $p \in \{ 0.0, 0.5, 0.9 \} $ }

# %%
# loss, mse, smape
metric = 'smape'

# %%
## Analysis

import json

import pandas as pd

import torch

import matplotlib.pyplot as plt

from cgtnnlib.Report import Report
from cgtnnlib.LearningTask import is_classification_task
from cgtnnlib.analyze import plot_deviant_curves_on_ax_or_plt
from cgtnnlib.constants import NOISE_FACTORS
from cgtnnlib.evaluate import eval_report_at_path, super_eval_model
from cgtnnlib.nn.AugmentedReLUNetworkMultilayer import AugmentedReLUNetworkMultilayer


model_type = AugmentedReLUNetworkMultilayer



def read_json(path: str) -> dict:
    with open(path) as file:
        return json.load(file)

def summarize_series_list(series_list: list[pd.Series]):
    df = pd.DataFrame(series_list).T

    summary_df = pd.DataFrame({
        0.25: df.quantile(0.25, axis=1),
        0.75: df.quantile(0.75, axis=1),
        'mean': df.mean(axis=1),
    })

    return summary_df


def make_ax_drawer(
    read_json,
    dataset,
    ng_maker,
    p,
):
    noise_generator = ng_maker(dataset)

    def report_patha(N):
        return report_path(dataset, p, noise_generator, N)

    def model_patha(N):
        return model_path(dataset, p, noise_generator, N)

    def read_eval_from_iteration(n) -> pd.DataFrame:
        path = report_patha(n)
        report = Report.from_path(path)
        # model_path = model_path(n)
        
        model = model_type(
            inputs_count=dataset.features_count,
            outputs_count=dataset.classes_count,
            p=p,
            inner_layer_size=inner_layer_size,
            hidden_layers_count=hidden_layers_count,
        )
        model.eval()
        model.load_state_dict(torch.load(model_patha(n)))
        super_eval_model(
            dataset=dataset,
            model=model,
            report=report,
        )
        print('read_eval_from_iteration', path, n)
        return pd.DataFrame(read_json(path)['eval'])
    
    def read_loss_from_iteration(n) -> pd.DataFrame:
        path = report_patha(n)
        json = read_json(path)
        return pd.DataFrame({ 'loss': json['loss'] })

    files = [
        read_eval_from_iteration(n)
        for n in range(iterations)
    ]
            
    print(f'Processing {report_patha(0)}...')

    curve = summarize_series_list([file[metric] for file in files])

    def draw_ax(ax):
        plot_deviant_curves_on_ax_or_plt(
            ax_or_plt=ax,
            models=[{
                'curve': curve,
                'color': 'purple',
                'label': 'Среднее',
                'quantiles_color': 'pink',
                'quantiles_label': 'Квартили 0,25; 0,75', 
            }],
            X=curve.index,
            title='\n'.join([
                f'{noise_generator.name}, p = {p}',
            ]),
            xlabel='Итерация',
            ylabel=metric,
            quantiles_alpha=0.5,
        )
    
    return draw_ax

ax_drawers = [
    [
        [make_ax_drawer(read_json, dataset, ng_maker, p) for p in pp]
        for ng_maker in ng_makers
    ]
    for dataset in datasets
]

print(ax_drawers)
(nrows, ncols) = (
    len(ax_drawers[0]),
    len(ax_drawers[0][0]),
)

print(f'Size: {nrows}x{ncols}')

for i, dataset in enumerate(datasets):
    fig, axes = plt.subplots(nrows, ncols, figsize=(15, 40))

    for j in range(nrows):
        for k in range(ncols):
            ax_drawers[i][j][k](axes[j, k])
    
    fig.suptitle(f'Датасет #{dataset.number}: {dataset.name}\{model_type}', fontsize=16)
    plt.tight_layout(rect=[0, 0.01, 1, 0.95]) # rect adjusts space for suptitle
    plt.show()
# Out:
# <string>:133: SyntaxWarning: invalid escape sequence '\{'
# <>:133: SyntaxWarning: invalid escape sequence '\{'
# <string>:133: SyntaxWarning: invalid escape sequence '\{'
# <>:133: SyntaxWarning: invalid escape sequence '\{'
# /var/folders/m9/y193wddj505gjbgjyvhjmzjm0000gq/T/ipykernel_54244/2405158979.py:133: SyntaxWarning: invalid escape sequence '\{'
#   fig.suptitle(f'Датасет #{dataset.number}: {dataset.name}\{model_type}', fontsize=16)
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset9_p0.0_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseNoNoise/9.json 9
# Processing rev9.3/dataset9_p0.0_noiseNoNoise/0.json...
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset9_p0.5_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseNoNoise/9.json 9
# Processing rev9.3/dataset9_p0.5_noiseNoNoise/0.json...
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset9_p0.9_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseNoNoise/9.json 9
# Processing rev9.3/dataset9_p0.9_noiseNoNoise/0.json...
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/0.json 0
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/1.json 1
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/2.json 2
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/3.json 3
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/4.json 4
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/5.json 5
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/6.json 6
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/7.json 7
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/8.json 8
# Report found at rev9.3/dataset9_p0.0_noiseTDS9/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseTDS9/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseTDS9/9.json 9
# Processing rev9.3/dataset9_p0.0_noiseTDS9/0.json...
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/0.json 0
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/1.json 1
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/2.json 2
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/3.json 3
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/4.json 4
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/5.json 5
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/6.json 6
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/7.json 7
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/8.json 8
# Report found at rev9.3/dataset9_p0.5_noiseTDS9/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseTDS9/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseTDS9/9.json 9
# Processing rev9.3/dataset9_p0.5_noiseTDS9/0.json...
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/0.json 0
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/1.json 1
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/2.json 2
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/3.json 3
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/4.json 4
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/5.json 5
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/6.json 6
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/7.json 7
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/8.json 8
# Report found at rev9.3/dataset9_p0.9_noiseTDS9/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseTDS9/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseTDS9/9.json 9
# Processing rev9.3/dataset9_p0.9_noiseTDS9/0.json...
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.0_noiseStable9A1B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.5_noiseStable9A1B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.9_noiseStable9A1B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A1.12B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.0_noiseStable9A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A1.12B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.5_noiseStable9A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A1.12B0F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset9_p0.9_noiseStable9A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.0_noiseStable9A2.0B1F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset9_p0.0_noiseStable9A2.0B1F0.03/0.json...
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.5_noiseStable9A2.0B1F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset9_p0.5_noiseStable9A2.0B1F0.03/0.json...
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/0.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/1.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/2.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/3.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/4.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/5.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/6.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/7.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/8.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset9_p0.9_noiseStable9A2.0B1F0.03/9.json
# read_eval_from_iteration rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset9_p0.9_noiseStable9A2.0B1F0.03/0.json...
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset10_p0.0_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseNoNoise/9.json 9
# Processing rev9.3/dataset10_p0.0_noiseNoNoise/0.json...
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset10_p0.5_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseNoNoise/9.json 9
# Processing rev9.3/dataset10_p0.5_noiseNoNoise/0.json...
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/0.json 0
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/1.json 1
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/2.json 2
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/3.json 3
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/4.json 4
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/5.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/5.json 5
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/6.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/6.json 6
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/7.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/7.json 7
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/8.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/8.json 8
# Report found at rev9.3/dataset10_p0.9_noiseNoNoise/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseNoNoise/9.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseNoNoise/9.json 9
# Processing rev9.3/dataset10_p0.9_noiseNoNoise/0.json...
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/0.json 0
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/1.json 1
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/2.json 2
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/3.json 3
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/4.json 4
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/5.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/5.json 5
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/6.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/6.json 6
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/7.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/7.json 7
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/8.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/8.json 8
# Report found at rev9.3/dataset10_p0.0_noiseTDS10/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.0_noiseTDS10/9.json
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseTDS10/9.json 9
# Processing rev9.3/dataset10_p0.0_noiseTDS10/0.json...
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/0.json 0
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/1.json 1
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/2.json 2
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/3.json 3
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/4.json 4
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/5.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/5.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/5.json 5
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/6.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/6.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/6.json 6
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/7.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/7.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/7.json 7
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/8.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/8.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/8.json 8
# Report found at rev9.3/dataset10_p0.5_noiseTDS10/9.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.5_noiseTDS10/9.json
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseTDS10/9.json 9
# Processing rev9.3/dataset10_p0.5_noiseTDS10/0.json...
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/0.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseTDS10/0.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseTDS10/0.json 0
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/1.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseTDS10/1.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseTDS10/1.json 1
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/2.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseTDS10/2.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseTDS10/2.json 2
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/3.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseTDS10/3.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseTDS10/3.json 3
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/4.json. Loading...
# Report loaded.
# ... Skipping evaluation of dataset10_p0.9_noiseTDS10/4.json
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseTDS10/4.json 4
# Report found at rev9.3/dataset10_p0.9_noiseTDS10/5.json. Loading...
# Report loaded.
# ...
# Report found at rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset10_p0.0_noiseStable10A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/0.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/0.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/0.json 0
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/1.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/1.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/1.json 1
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/2.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/2.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/2.json 2
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/3.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/3.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/3.json 3
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/4.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/4.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/4.json 4
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset10_p0.5_noiseStable10A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/0.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/0.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/0.json 0
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/1.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/1.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/1.json 1
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/2.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/2.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/2.json 2
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/3.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/3.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/3.json 3
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/4.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/4.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/4.json 4
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/9.json 9
# Processing rev9.3/dataset10_p0.9_noiseStable10A1.12B0F0.03/0.json...
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/0.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/0.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/1.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/1.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/2.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/2.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/3.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/3.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/4.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/4.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset10_p0.0_noiseStable10A2.0B1F0.03/0.json...
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/0.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/0.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/1.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/1.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/2.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/2.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/3.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/3.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/4.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/4.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset10_p0.5_noiseStable10A2.0B1F0.03/0.json...
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/0.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/0.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/0.json 0
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/1.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/1.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/1.json 1
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/2.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/2.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/2.json 2
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/3.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/3.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/3.json 3
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/4.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/4.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/4.json 4
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/5.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/5.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/5.json 5
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/6.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/6.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/6.json 6
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/7.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/7.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/7.json 7
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/8.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/8.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/8.json 8
# Report found at rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/9.json. Loading...
# Report loaded.
# Report saved to rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/9.json.
# read_eval_from_iteration rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/9.json 9
# Processing rev9.3/dataset10_p0.9_noiseStable10A2.0B1F0.03/0.json...
# [[[<function make_ax_drawer.<locals>.draw_ax at 0x110fe65c0>, <function make_ax_drawer.<locals>.draw_ax at 0x15b70b060>, <function make_ax_drawer.<locals>.draw_ax at 0x15b7091c0>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c5fede0>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff420>, <function make_ax_drawer.<locals>.draw_ax at 0x15b708f40>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c5ffa60>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff740>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5fc040>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c5fee80>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff380>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff560>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c5ffd80>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff4c0>, <function make_ax_drawer.<locals>.draw_ax at 0x15c648720>]], [[<function make_ax_drawer.<locals>.draw_ax at 0x15c5ff920>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff1a0>, <function make_ax_drawer.<locals>.draw_ax at 0x15c5ff100>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c5ff240>, <function make_ax_drawer.<locals>.draw_ax at 0x15c649300>, <function make_ax_drawer.<locals>.draw_ax at 0x15c6482c0>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c649580>, <function make_ax_drawer.<locals>.draw_ax at 0x15c6496c0>, <function make_ax_drawer.<locals>.draw_ax at 0x15c649620>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c648860>, <function make_ax_drawer.<locals>.draw_ax at 0x15c648900>, <function make_ax_drawer.<locals>.draw_ax at 0x15c648ae0>], [<function make_ax_drawer.<locals>.draw_ax at 0x15c648c20>, <function make_ax_drawer.<locals>.draw_ax at 0x15c648180>, <function make_ax_drawer.<locals>.draw_ax at 0x15c6491c0>]]]
# Size: 5x3

# %% [markdown]
# ### Trying 5 layers
#
# Smape goes down (p = 0):
# - 0.1 -> 0.08
# - 0.10 -> 0.085
# - 0.10 -> 0.085
# - 0.09 ~> 0.095 (goes up on Stble4A.12B0F0.03)
# - 0.11 -> 0.085

# %%
import numpy as np
np.abs(np.array([
    0.1 - 0.08,
    0.1 - 0.085,
    0.10 - 0.085,
    0.09 - 0.095,
    0.11 - 0.085,
])).mean()
# Out:
# 0.016

# %% [markdown]
# So we gain ~0.016 of sMAPE for adding 2 layers

# %%
x = 610 / 350 * 759
x
# Out:
# 1322.8285714285714

# %% [markdown]
# ## References
#
# 1. Chambers, J. M., Mallows, C. L., & Stuck, B. W. (1976). A method for simulating stable random variables. *Journal of the American Statistical Association*, *71*(354), 340-344.
# 2. M. Firouzi, A. Mohammadpour. A Survey on Simulating Stable Random Variables. URL: https://www.semanticscholar.org/reader/11a1e93642dc0a5c94e6906bcca5e4d25d4e9d46
